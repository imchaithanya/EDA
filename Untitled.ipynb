# %%
# !pip install pandas numpy matplotlib seaborn plotly
# Out:
# Requirement already satisfied: pandas in c:\users\imvc4\eda\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\imvc4\eda\venv\lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\users\imvc4\eda\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\imvc4\eda\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\imvc4\eda\venv\lib\site-packages (6.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\imvc4\eda\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\imvc4\eda\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\imvc4\eda\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\imvc4\eda\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\imvc4\eda\venv\lib\site-packages (from plotly) (2.10.1)
# Requirement already satisfied: six>=1.5 in c:\users\imvc4\eda\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("hello")
# Out:
# hello

# %%
# !where python
# Out:
# C:\Users\imvc4\EDA\venv\Scripts\python.exe
# C:\Program Files\Python313\python.exe
